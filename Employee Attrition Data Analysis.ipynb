# %% [markdown]
# ### Problem Statement:
#
# XYZ company which was established a few years back is facing around a 15% attrition rate for
# a couple of years. And it's majorly affecting the company in many aspects. In order to
# understand why employees are leaving the company and reduce the attrition rate XYZ
# company has approached an HR analytics consultancy for analyzing the data they have. You
# are playing the HR analyst role in this project and building a dashboard which can help the
# organization in making data-driven decisions.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
os.chdir(r"C:\Users\ASUS\Desktop\niladri - nitai\Subhro")
data = pd.read_csv("Attrition data.csv")
data.head(2)
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  \
# 0                 6          2  Life Sciences              1  Female
# 1                10          1  Life Sciences              1  Female
#
#    JobLevel                    JobRole MaritalStatus  MonthlyIncome  \
# 0         1  Healthcare Representative       Married         131160
# 1         1         Research Scientist        Single          41890
#
#    NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# 0                 1.0      Y                 11              8
# 1                 0.0      Y                 23              8
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# ...

# %% [markdown]
# ### Checking for missing values

# %%
data.isnull().mean()*100
# Out:
# EmployeeID                 0.000000
# Age                        0.000000
# Attrition                  0.000000
# BusinessTravel             0.000000
# Department                 0.000000
# DistanceFromHome           0.000000
# Education                  0.000000
# EducationField             0.000000
# EmployeeCount              0.000000
# Gender                     0.000000
# JobLevel                   0.000000
# JobRole                    0.000000
# MaritalStatus              0.000000
# MonthlyIncome              0.000000
# NumCompaniesWorked         0.430839
# Over18                     0.000000
# PercentSalaryHike          0.000000
# StandardHours              0.000000
# StockOptionLevel           0.000000
# TotalWorkingYears          0.204082
# TrainingTimesLastYear      0.000000
# YearsAtCompany             0.000000
# YearsSinceLastPromotion    0.000000
# YearsWithCurrManager       0.000000
# EnvironmentSatisfaction    0.566893
# JobSatisfaction            0.453515
# ...

# %%
# We notice that few variables are having missing values, which are less than 1%. 
# Hence, we are deleting all the rows with missing values
data =  data.dropna()

# %% [markdown]
# ### Creating different dashboards with respect to Attrition

# %%
ax = sns.catplot(data=data, kind="bar",
x="Department",y="EmployeeCount", hue="Attrition",
estimator=sum,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by Department', weight='bold').set_fontsize('18')

# Research & Development has maximum attrition, followed by Sales departmnet

# %%
ax = sns.catplot(data=data, kind="bar",
x="BusinessTravel",y="JobLevel", hue="Attrition",
estimator=sum,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by BusinessTravel', weight='bold').set_fontsize('18')

# Employee who Travel_Rarely has maximum attrition, followed by Travel_frequently

# %%
ax = sns.catplot(data=data, kind="bar",
x="EducationField",y="Education", hue="Attrition",
estimator=sum,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by EducationField', weight='bold').set_fontsize('18')

# Life Science has maximum attrition, followed by Medical

# %%
ax = sns.catplot(data=data, kind="bar",
x="JobRole",y="PerformanceRating", hue="Attrition",
estimator=sum,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by JobRole', weight='bold').set_fontsize('18')

# Research Scientist and Sales Executive has maximum attrition, followed by Laboratory Technician

# %%
ax = sns.catplot(data=data, kind="bar",
x="Gender",y="MonthlyIncome", hue="Attrition",
estimator=sum,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by Gender', weight='bold').set_fontsize('18')

# Male has maximum attrition, followed by Female

# %%
ax = sns.catplot(data=data, kind="bar",
x="MaritalStatus",y="WorkLifeBalance", hue="Attrition",
estimator=sum,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by MaritalStatus', weight='bold').set_fontsize('18')

# Single has maximum attrition, followed by Married

# %% [markdown]
# ### Creating different dashboards with respect to Distance From Home

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="DistanceFromHome",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by Distance From Home', weight='bold').set_fontsize('18')

## It seems that attrition doesn't depend on the distance from home, since attrition is happening irrespective of the distance.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="NumCompaniesWorked",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by NumCompaniesWorked', weight='bold').set_fontsize('18')

# attrition depends on the NumCompaniesWorked.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="PercentSalaryHike",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by PercentSalaryHike', weight='bold').set_fontsize('18')

# attrition depends on the PercentSalaryHike.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="StandardHours",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by StandardHours', weight='bold').set_fontsize('18')

# attrition doesn't depend on the StandardHours.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="StockOptionLevel",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by StockOptionLevel', weight='bold').set_fontsize('18')

# attrition doesn't depend on the StockOptionLevel.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="TotalWorkingYears",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by TotalWorkingYears', weight='bold').set_fontsize('18')

# attrition depends on the StockOptionLevel.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="TrainingTimesLastYear",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by TrainingTimesLastYear', weight='bold').set_fontsize('18')

# attrition depends on the TrainingTimesLastYear.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="YearsAtCompany",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by YearsAtCompany', weight='bold').set_fontsize('18')

# attrition depends on the YearsAtCompany.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="YearsSinceLastPromotion",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by YearsSinceLastPromotion', weight='bold').set_fontsize('18')

# attrition depends on the YearsSinceLastPromotion.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="YearsWithCurrManager",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by YearsWithCurrManager', weight='bold').set_fontsize('18')

# attrition depends on the YearsWithCurrManager.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="EnvironmentSatisfaction",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by EnvironmentSatisfaction', weight='bold').set_fontsize('18')

# attrition depends on the EnvironmentSatisfaction.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="JobSatisfaction",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by JobSatisfaction', weight='bold').set_fontsize('18')

# attrition depends on the JobSatisfaction.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="WorkLifeBalance",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by WorkLifeBalance', weight='bold').set_fontsize('18')

# attrition depends on the WorkLifeBalance.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="JobInvolvement",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by JobInvolvement', weight='bold').set_fontsize('18')

# attrition doesn't depend on the JobInvolvement.

# %%
ax = sns.catplot(data=data, kind="bar",
x="Attrition",y="PerformanceRating",
estimator=np.mean,ci=False)
ax.figure.set_size_inches(14, 4)
plt.title('Attrition by PerformanceRating', weight='bold').set_fontsize('18')

# attrition doesn't depend on the PerformanceRating.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import os
from matplotlib import pylab
import pylab as pl

# %%
# Checking for outliers

def outlier (data,age):
 Q1 = data[age].quantile(0.25)
 Q3 = data[age].quantile(0.75)
 IQR = Q3 - Q1
 data= data.loc[~((data[age] < (Q1 - 1.5 * IQR)) | (data[age] > (Q3 + 1.5 * IQR))),]
 return data

# %%
data.boxplot(column=["Age"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["DistanceFromHome"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["Education"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["JobLevel"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["MonthlyIncome"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"MonthlyIncome")

# %%
data.boxplot(column=["MonthlyIncome"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["NumCompaniesWorked"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"NumCompaniesWorked")

# %%
data.boxplot(column=["NumCompaniesWorked"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["PercentSalaryHike"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["StockOptionLevel"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"StockOptionLevel")

# %%
data.boxplot(column=["StockOptionLevel"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["TotalWorkingYears"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"TotalWorkingYears")

# %%
data.boxplot(column=["TotalWorkingYears"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["TrainingTimesLastYear"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"TrainingTimesLastYear")

# %%
data.boxplot(column=["TrainingTimesLastYear"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["YearsAtCompany"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"YearsAtCompany")

# %%
data.boxplot(column=["YearsAtCompany"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["YearsSinceLastPromotion"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"YearsSinceLastPromotion")

# %%
data.boxplot(column=["YearsSinceLastPromotion"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["YearsWithCurrManager"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"YearsWithCurrManager")

# %%
data.boxplot(column=["YearsWithCurrManager"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["EnvironmentSatisfaction"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["JobSatisfaction"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["WorkLifeBalance"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["JobInvolvement"])
# Out:
# <AxesSubplot:>

# %%
data.boxplot(column=["PerformanceRating"])
# Out:
# <AxesSubplot:>

# %%
data = outlier(data,"PerformanceRating")

# %%
data.boxplot(column=["PerformanceRating"])
# Out:
# <AxesSubplot:>

# %%
# missing value treatment

data.isnull().mean()*100
# Out:
# EmployeeID                 0.0
# Age                        0.0
# Attrition                  0.0
# BusinessTravel             0.0
# Department                 0.0
# DistanceFromHome           0.0
# Education                  0.0
# EducationField             0.0
# EmployeeCount              0.0
# Gender                     0.0
# JobLevel                   0.0
# JobRole                    0.0
# MaritalStatus              0.0
# MonthlyIncome              0.0
# NumCompaniesWorked         0.0
# Over18                     0.0
# PercentSalaryHike          0.0
# StandardHours              0.0
# StockOptionLevel           0.0
# TotalWorkingYears          0.0
# TrainingTimesLastYear      0.0
# YearsAtCompany             0.0
# YearsSinceLastPromotion    0.0
# YearsWithCurrManager       0.0
# EnvironmentSatisfaction    0.0
# JobSatisfaction            0.0
# WorkLifeBalance            0.0
# JobInvolvement             0.0
# PerformanceRating          0.0
# dtype: float64

# %%
data = data.dropna()

# %%
data.isnull().mean()*100
# Out:
# EmployeeID                 0.0
# Age                        0.0
# Attrition                  0.0
# BusinessTravel             0.0
# Department                 0.0
# DistanceFromHome           0.0
# Education                  0.0
# EducationField             0.0
# EmployeeCount              0.0
# Gender                     0.0
# JobLevel                   0.0
# JobRole                    0.0
# MaritalStatus              0.0
# MonthlyIncome              0.0
# NumCompaniesWorked         0.0
# Over18                     0.0
# PercentSalaryHike          0.0
# StandardHours              0.0
# StockOptionLevel           0.0
# TotalWorkingYears          0.0
# TrainingTimesLastYear      0.0
# YearsAtCompany             0.0
# YearsSinceLastPromotion    0.0
# YearsWithCurrManager       0.0
# EnvironmentSatisfaction    0.0
# JobSatisfaction            0.0
# WorkLifeBalance            0.0
# JobInvolvement             0.0
# PerformanceRating          0.0
# dtype: float64

# %%
# converting the dependent variable from charecter to numeric

data["attrition"] = np.where((data["Attrition"] == "Yes"),"0","1")

# %%
# deleting the original dependent variable from the dataset

data = data.drop(["Attrition"], axis = 1)

# %%
data.head(2)
# Out:
#    EmployeeID  Age     BusinessTravel              Department  \
# 1           2   31  Travel_Frequently  Research & Development
# 4           5   32      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  \
# 1                10          1  Life Sciences              1  Female
# 4                10          1        Medical              1    Male
#
#    JobLevel             JobRole MaritalStatus  MonthlyIncome  \
# 1         1  Research Scientist        Single          41890
# 4         1     Sales Executive        Single          23420
#
#    NumCompaniesWorked Over18  PercentSalaryHike  StandardHours  \
# 1                 0.0      Y                 23              8
# 4                 4.0      Y                 12              8
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 1                 1                6.0                      3               5
# ...

# %%
# segregating categorical variables

cat = data.loc[:,["BusinessTravel","Department","EducationField","Gender","JobRole","MaritalStatus","Over18"]]

# %%
cat.head()
# Out:
#       BusinessTravel              Department EducationField  Gender  \
# 0      Travel_Rarely                   Sales  Life Sciences  Female
# 2  Travel_Frequently  Research & Development          Other    Male
# 3         Non-Travel  Research & Development  Life Sciences    Male
# 4      Travel_Rarely  Research & Development        Medical    Male
# 5      Travel_Rarely  Research & Development  Life Sciences  Female
#
#                      JobRole MaritalStatus Over18
# 0  Healthcare Representative       Married      Y
# 2            Sales Executive       Married      Y
# 3            Human Resources       Married      Y
# 4            Sales Executive        Single      Y
# 5          Research Director       Married      Y

# %%
# dropping the original categorical variables

data = data.drop(["BusinessTravel","Department","EducationField","Gender","JobRole","MaritalStatus","Over18"],axis=1)

# %%
# creating dummy variables

dum = pd.get_dummies(cat.astype(str),drop_first=True)

# %%
dum.head()
# Out:
#    BusinessTravel_Travel_Frequently  BusinessTravel_Travel_Rarely  \
# 0                                 0                             1
# 2                                 1                             0
# 3                                 0                             0
# 4                                 0                             1
# 5                                 0                             1
#
#    Department_Research & Development  Department_Sales  \
# 0                                  0                 1
# 2                                  1                 0
# 3                                  1                 0
# 4                                  1                 0
# 5                                  1                 0
#
#    EducationField_Life Sciences  EducationField_Marketing  \
# 0                             1                         0
# 2                             0                         0
# ...

# %%
# concatenating the columns

data = pd.concat([data,dum],axis=1)

# %%
data.head(2)
# Out:
#    EmployeeID  Age  DistanceFromHome  Education  EmployeeCount  JobLevel  \
# 1           2   31                10          1              1         1
# 4           5   32                10          1              1         1
#
#    MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  StandardHours  \
# 1          41890                 0.0                 23              8
# 4          23420                 4.0                 12              8
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 1                 1                6.0                      3               5
# 4                 2                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# 1                        1                     4                      3.0
# 4                        0                     4                      4.0
#
# ...

# %%
# Emp id is not going to help in the model, hence deleting it

data = data.drop("EmployeeID",axis=1)

# %%
data.head(2)
# Out:
#    Age  DistanceFromHome  Education  EmployeeCount  JobLevel  MonthlyIncome  \
# 1   31                10          1              1         1          41890
# 4   32                10          1              1         1          23420
#
#    NumCompaniesWorked  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 1                 0.0                 23              8                 1
# 4                 4.0                 12              8                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 1                6.0                      3               5
# 4                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# 1                        1                     4                      3.0
# 4                        0                     4                      4.0
#
#    JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating  \
# ...

# %%
data["attrition"] = data["attrition"].astype("float")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2421 entries, 1 to 4407
# Data columns (total 41 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                2421 non-null   int64
#  1   DistanceFromHome                   2421 non-null   int64
#  2   Education                          2421 non-null   int64
#  3   EmployeeCount                      2421 non-null   int64
#  4   JobLevel                           2421 non-null   int64
#  5   MonthlyIncome                      2421 non-null   int64
#  6   NumCompaniesWorked                 2421 non-null   float64
#  7   PercentSalaryHike                  2421 non-null   int64
#  8   StandardHours                      2421 non-null   int64
#  9   StockOptionLevel                   2421 non-null   int64
#  10  TotalWorkingYears                  2421 non-null   float64
# ...

# %% [markdown]
# ## Independent variables

# %%
inputData = data.drop("attrition",axis=1)
inputData.head(2)
# Out:
#    Age  DistanceFromHome  Education  EmployeeCount  JobLevel  MonthlyIncome  \
# 1   31                10          1              1         1          41890
# 4   32                10          1              1         1          23420
#
#    NumCompaniesWorked  PercentSalaryHike  StandardHours  StockOptionLevel  \
# 1                 0.0                 23              8                 1
# 4                 4.0                 12              8                 2
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# 1                6.0                      3               5
# 4                9.0                      2               6
#
#    YearsSinceLastPromotion  YearsWithCurrManager  EnvironmentSatisfaction  \
# 1                        1                     4                      3.0
# 4                        0                     4                      4.0
#
#    JobSatisfaction  WorkLifeBalance  JobInvolvement  PerformanceRating  \
# ...

# %% [markdown]
# ## Dependent variables

# %%
outputData =data.loc[:,"attrition"]
outputData.head()
# Out:
# 1     0.0
# 4     1.0
# 6     0.0
# 9     1.0
# 14    1.0
# Name: attrition, dtype: float64

# %%
train_cols = data.loc[:,["EmployeeID","Age","DistanceFromHome","Education","EmployeeCount","JobLevel","MonthlyIncome",
"NumCompaniesWorked","PercentSalaryHike","StandardHours","StockOptionLevel","TotalWorkingYears","TrainingTimesLastYear",
"YearsAtCompany","YearsSinceLastPromotion","YearsWithCurrManager","EnvironmentSatisfaction","JobSatisfaction","WorkLifeBalance",
"JobInvolvement","PerformanceRating","BusinessTravel_Travel_Frequently","BusinessTravel_Travel_Rarely",
"Department_Research & Development","Department_Sales","EducationField_Life Sciences","EducationField_Marketing",
"EducationField_Medical","EducationField_Other","EducationField_Technical Degree","Gender_Male","JobRole_Human Resources",
"JobRole_Laboratory Technician","JobRole_Manager","JobRole_Manufacturing Director","JobRole_Research Director",
"JobRole_Research Scientist","JobRole_Sales Executive","JobRole_Sales Representative","MaritalStatus_Married",
"MaritalStatus_Single"]]

# %% [markdown]
# ## Run Logistic Regression model

# %%
logit = sm.Logit(outputData, inputData) # setting up the model

result = logit.fit() # run the model

result.summary() # shows the result
# Out:
# Optimization terminated successfully.
#          Current function value: 0.342068
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:              attrition   No. Observations:                 2421
# Model:                          Logit   Df Residuals:                     2382
# Method:                           MLE   Df Model:                           38
# Date:                Fri, 17 May 2024   Pseudo R-squ.:                  0.2533
# Time:                        09:33:09   Log-Likelihood:                -828.15
# converged:                       True   LL-Null:                       -1109.1
# Covariance Type:            nonrobust   LLR p-value:                 1.873e-94
# ...
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Run Random Forest  model

# %%
X = data.drop("attrition", axis=1)
Y = data["attrition"]



# split the dataset into 70% training and 30% testing

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)


from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000,random_state=0)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[107  17]
#  [  0 603]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.86      0.93       124
#          1.0       0.97      1.00      0.99       603
#
#     accuracy                           0.98       727
#    macro avg       0.99      0.93      0.96       727
# weighted avg       0.98      0.98      0.98       727
#
# 0.9766162310866575

# %% [markdown]
# ## Run XGBoost  model

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import warnings
warnings.filterwarnings("ignore", category=UserWarning)


X = data.drop("attrition", axis=1)
Y = data["attrition"]



# split the dataset into 70% training and 30% testing

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)


import xgboost as xgb
from xgboost import XGBClassifier
classifier =XGBClassifier()
classifier.fit(X_train, y_train)
y_pred = rf.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [09:45:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [[107  17]
#  [  0 603]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.86      0.93       124
#          1.0       0.97      1.00      0.99       603
#
#     accuracy                           0.98       727
#    macro avg       0.99      0.93      0.96       727
# weighted avg       0.98      0.98      0.98       727
#
# 0.9766162310866575
